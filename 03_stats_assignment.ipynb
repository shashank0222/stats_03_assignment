# %% [markdown]
# Q1. What is the Probability density function?

# %% [markdown]
# Solution :

# %% [markdown]
# A probability density function (PDF) is used to define the random variable’s probability coming within a distinct range of values, as opposed to taking on any one value.
#
# PDF (probability density function ) is defined for continuous random variables

# %% [markdown]
# Q2. What are the types of Probability distribution?

# %% [markdown]
# Types of probability distribution are :
#
# 1. Normal distribution(pdf)
#
# 2. Binomial distribution(pmf)
#
# 3. poission distribution(pmf)
#
# 4. Bernoulli distribution(pmf)
#
# 5. Log Normal distribution(pdf)
#
# 6. Uniform distribution(pmf)
#
# 7. Power Law Distribution(pdf)

# %% [markdown]
# Q3. Write a Python function to calculate the probability density function of a normal distribution with
# given mean and standard deviation at a given point.

# %% [markdown]
# Solution:

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pylab
from scipy import stats

# %%
arr = np.random.normal(loc = 4 , scale = 2 , size = 500)

# %%
arr
# Out:
# array([ 6.47003888e+00,  3.02591114e+00,  5.42023828e+00,  2.33575939e+00,
#         3.42909702e+00,  9.84672353e+00,  4.40204660e+00,  6.66169113e+00,
#         4.03372980e+00,  5.34858824e-01,  3.81671463e+00,  6.33608018e+00,
#         2.68935075e+00,  4.56892824e+00,  3.43537708e-01,  2.52599255e+00,
#         5.49232721e-01,  1.73186738e+00,  1.75095566e+00,  5.17079074e+00,
#         4.81984793e+00,  5.70976613e+00,  4.68372544e+00,  2.54421752e+00,
#         6.43987741e+00,  8.78918368e-01,  1.40758896e+00,  4.27886965e+00,
#         5.20420204e+00,  1.19054259e+00,  4.87382811e+00, -2.34875884e-01,
#         8.99016708e+00,  4.92463602e+00,  2.74056359e+00,  1.85927410e+00,
#         3.84045887e+00,  2.06801329e+00,  1.80424369e+00,  2.77467226e+00,
#         3.01690605e-02,  3.91885588e+00,  6.89694128e+00,  6.61252111e+00,
#         2.47344557e+00,  2.44357297e+00,  3.67542230e+00,  6.18785851e+00,
# ...

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
sns.histplot(arr , kde = True)

plt.subplot(1,2,2)
stats.probplot(arr,dist = "norm" , plot = pylab)

plt.show()

# %% [markdown]
#   formula to calculate pdf of a normal distribution =
#
#   ![image.png](attachment:d34c332f-d99b-4ec4-bb1e-2b459dec4220.png)

# %%
import math

def pdf(x,mean,std):
    var = float(std)**2
    denom = (2*math.pi*var)**0.5
    num = math.exp(-(float(x) - float(mean))**2/(2*var))
    return num/denom

# %%
res = pdf(50,mean = np.mean(arr), std = np.std(arr))

# %%
res
# Out:
# 0.032786643008494994

# %% [markdown]
# # using scipy

# %%
stats.norm.pdf(x = 50 , loc = np.mean(arr) , scale = np.std(arr))
# Out:
# 8.735365248368851e-119

# %% [markdown]
# ## Q4. What are the properties of Binomial distribution? Give two examples of events where binomial distribution can be applied.

# %% [markdown]
# Solution:

# %% [markdown]
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, either Success or Failure. For example, if we toss a coin, there could be only two possible outcomes: heads or tails.
#
# In binomial probability distribution, the number of ‘Success’ in a sequence of n experiments, where each time a question is asked for yes-no, then the boolean-valued outcome is represented either with success/yes/true/one (probability p) or failure/no/false/zero (probability q = 1 − p). A single success/failure test is also called a Bernoulli trial or Bernoulli experiment, and a series of outcomes is called a Bernoulli process. For n = 1, i.e. a single experiment, the binomial distribution is a Bernoulli distribution.
#
#
# Properties :
#
# 1. There are two possible outcomes: true or false, success or failure, yes or no.
#
# 2. There is ‘n’ number of independent trials or a fixed number of n times repeated trials.
#
# 3. The probability of success or failure remains the same for each trial.
#
# 4. Only the number of success is calculated out of n independent trials.
#
# 5. Every trial is an independent trial, which means the outcome of one trial does not affect the outcome of another trial.
#
#
# Examples where binomial distribution can be applied :
#
# 1. Taking a survey of positive and negative reviews from the public for any specific product or place.
#
# 2. By using the YES/ NO survey, we can check whether the number of persons views the particular channel.
#
# 3. To find the number of male and female employees in an organisation.
#
# 4. The number of votes collected by a candidate in an election is counted based on 0 or 1 probability.

# %% [markdown]
# # Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4 and plot a histogram of the results using matplotlib.

# %% [markdown]
# # Solution

# %%
arr = np.random.binomial(n = 10 , p = 0.4 , size = 1000)

# %%
arr
# Out:
# array([3, 4, 4, 4, 6, 6, 3, 2, 3, 1, 5, 4, 3, 1, 2, 4, 5, 2, 2, 6, 5, 7,
#        6, 5, 6, 5, 2, 5, 5, 3, 7, 6, 3, 3, 6, 7, 6, 4, 5, 3, 3, 5, 5, 5,
#        4, 2, 3, 5, 3, 4, 5, 4, 5, 5, 5, 4, 4, 5, 4, 3, 2, 2, 4, 5, 1, 4,
#        4, 5, 3, 4, 4, 5, 2, 5, 5, 3, 5, 6, 3, 6, 5, 2, 2, 4, 5, 4, 3, 3,
#        4, 5, 3, 6, 3, 4, 4, 6, 4, 3, 2, 3, 5, 5, 5, 3, 8, 1, 2, 5, 4, 3,
#        6, 3, 2, 4, 3, 4, 4, 4, 4, 6, 4, 3, 3, 6, 4, 3, 5, 2, 3, 2, 3, 4,
#        4, 3, 2, 2, 2, 4, 4, 5, 2, 5, 3, 6, 4, 2, 4, 3, 5, 6, 2, 3, 3, 4,
#        4, 3, 3, 3, 3, 5, 3, 5, 8, 5, 5, 4, 2, 5, 4, 5, 4, 3, 2, 3, 6, 4,
#        6, 4, 3, 2, 4, 6, 6, 5, 3, 4, 1, 4, 4, 3, 1, 6, 6, 5, 5, 2, 5, 2,
#        4, 4, 5, 2, 1, 2, 3, 2, 4, 3, 8, 5, 4, 4, 3, 4, 5, 3, 2, 4, 2, 4,
#        3, 5, 3, 3, 2, 3, 3, 4, 4, 3, 6, 2, 4, 3, 6, 4, 6, 6, 3, 6, 4, 2,
#        4, 3, 5, 1, 6, 5, 3, 2, 1, 5, 4, 5, 5, 4, 6, 1, 3, 2, 4, 5, 4, 1,
#        1, 3, 5, 4, 1, 3, 5, 2, 5, 5, 5, 6, 4, 2, 6, 2, 5, 4, 6, 4, 5, 3,
# ...

# %%
plt.figure(figsize=(8,6))

sns.histplot(arr,kde = True)

plt.show()

# %% [markdown]
# if the sample size for the binomial distribution is very large, then the distribution curve for the binomial distribution is similar to the normal distribution curve.

# %%
arr = np.random.binomial(n = 1000 , p = 0.4 , size = 1000)

# %%
arr
# Out:
# array([422, 405, 396, 416, 398, 375, 404, 414, 382, 406, 378, 418, 390,
#        418, 387, 394, 398, 397, 371, 430, 435, 390, 414, 409, 392, 399,
#        404, 389, 414, 398, 420, 403, 404, 392, 404, 374, 401, 385, 400,
#        416, 380, 389, 403, 386, 402, 402, 417, 380, 391, 382, 398, 397,
#        417, 402, 411, 395, 404, 404, 398, 392, 414, 388, 404, 417, 369,
#        386, 397, 407, 399, 383, 422, 411, 380, 392, 403, 406, 392, 395,
#        385, 402, 428, 405, 414, 387, 404, 394, 390, 383, 411, 410, 375,
#        387, 392, 415, 380, 420, 423, 408, 376, 411, 405, 394, 397, 408,
#        373, 411, 404, 407, 405, 386, 425, 399, 405, 411, 421, 414, 403,
#        408, 382, 395, 408, 394, 421, 414, 411, 379, 380, 398, 385, 375,
#        385, 413, 393, 417, 410, 415, 417, 417, 419, 425, 376, 396, 390,
#        418, 435, 369, 393, 419, 387, 393, 391, 412, 392, 426, 417, 375,
#        402, 411, 398, 401, 398, 404, 401, 371, 414, 423, 423, 416, 394,
# ...

# %%
plt.figure(figsize=(8,6))

sns.histplot(arr,kde = True)

plt.show()

# %% [markdown]
# # Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution  with given mean at a given point.

# %%
arr = np.random.poisson(lam = 3 , size = 1000)

# %%
arr
# Out:
# array([ 4,  4,  5,  1,  2,  5,  6,  0, 10,  0,  2,  2,  1,  2,  3,  1,  4,
#         3,  2,  3,  4,  6,  2,  2,  2,  3,  1,  5,  2,  4,  1,  0,  2,  1,
#         2,  4,  3,  4,  5,  3,  2,  6,  3,  3,  2,  5,  0,  4,  2,  5,  1,
#         3,  6,  1,  3,  2,  0,  3,  4,  1,  3,  1,  5,  1,  2,  2,  2,  0,
#         4,  3,  2,  2,  0,  1,  1,  1,  1,  3,  1,  2,  4,  4,  1,  4,  5,
#         2,  4,  1,  1,  2,  4,  3,  3,  7,  3,  4,  2,  1,  2,  7,  1,  4,
#         2,  3,  1,  4,  5,  1,  4,  6,  5,  3,  3,  3,  2,  4,  3,  6,  1,
#         2,  4,  0,  7,  4,  5,  6,  4,  2,  2,  4,  3,  1,  1,  2,  1,  6,
#         2,  2,  4,  3,  1,  7,  8,  3,  4,  4,  2,  3,  5,  2,  4,  3,  1,
#         5,  1,  4,  2,  3,  5,  4,  1,  4,  3,  5,  1,  0,  2,  2,  0,  4,
#         2,  1,  3,  0,  2,  7,  3,  2,  3,  0,  4,  8,  4,  6,  1,  1,  2,
#         1,  3,  7,  2,  4,  2,  4,  3,  4,  2,  5,  6,  3,  4,  4,  3,  1,
# ...

# %%
stats.poisson.cdf(arr ,  mu = 3)
# Out:
# array([0.96649146, 0.96649146, 0.81526324, 0.64723189, 0.81526324,
#        0.9880955 , 0.81526324, 0.64723189, 0.91608206, 0.91608206,
#        0.64723189, 0.81526324, 0.42319008, 0.99619701, 0.64723189,
#        0.81526324, 0.96649146, 0.19914827, 0.96649146, 0.91608206,
#        0.81526324, 0.81526324, 0.81526324, 0.42319008, 0.64723189,
#        0.64723189, 0.42319008, 0.99619701, 0.81526324, 0.91608206,
#        0.19914827, 0.99889751, 0.91608206, 0.04978707, 0.96649146,
#        0.91608206, 0.91608206, 0.96649146, 0.91608206, 0.99619701,
#        0.81526324, 0.91608206, 0.64723189, 0.42319008, 0.81526324,
#        0.91608206, 0.9880955 , 0.96649146, 0.91608206, 0.9880955 ,
#        0.91608206, 0.64723189, 0.91608206, 0.9880955 , 0.91608206,
#        0.96649146, 0.9880955 , 0.96649146, 0.96649146, 0.99970766,
#        0.96649146, 0.9880955 , 0.64723189, 0.91608206, 0.96649146,
#        0.81526324, 0.96649146, 0.96649146, 0.91608206, 0.81526324,
# ...

# %% [markdown]
#  # Q7. How Binomial distribution different from Poisson distribution?

# %% [markdown]
# # Solution :

# %% [markdown]
# Binomial distribution only has two possible outcomes,
# whereas poisson distribution can have unlimited possible outcomes.
#
# But for very large n and near-zero p binomial distribution is near identical to
# poisson distribution such that n * p is nearly equal to lam.

# %%
arr = np.random.binomial(n = 1000 , p = 0.01  , size = 1000)

# %%
arr1 = np.random.poisson(lam=10,size = 1000)

# %%
plt.figure(figsize = (6,2))
plt.subplot(1,2,1)
sns.histplot(arr , kde=True)

plt.subplot(1,2,2)
sns.histplot(arr1,kde=True)

plt.show()

# %% [markdown]
# # Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the sample mean and variance.

# %%
arr = np.random.poisson(lam = 5 , size = 1000)

# %%
arr
# Out:
# array([ 6,  6,  4,  3,  4,  7,  4,  3,  5,  5,  3,  4,  2,  8,  3,  4,  6,
#         1,  6,  5,  4,  4,  4,  2,  3,  3,  2,  8,  4,  5,  1,  9,  5,  0,
#         6,  5,  5,  6,  5,  8,  4,  5,  3,  2,  4,  5,  7,  6,  5,  7,  5,
#         3,  5,  7,  5,  6,  7,  6,  6, 10,  6,  7,  3,  5,  6,  4,  6,  6,
#         5,  4,  6,  2,  4,  4,  4,  3,  4, 12,  3,  5,  3,  4,  5,  1,  5,
#         3,  5,  5,  6, 10,  4,  3,  2,  3,  8,  4,  9,  7,  3,  5,  6,  6,
#         8,  1,  3,  6,  3,  6,  6,  5,  3, 11,  7,  7,  7,  3,  5,  8,  3,
#         3,  6,  5,  5,  7,  7,  9,  3,  7,  6,  2,  5,  2, 11,  6,  4,  5,
#         3,  4,  8,  3,  6,  7,  3,  8,  3,  7,  3,  6,  2,  4,  3,  1,  0,
#         5,  5,  2,  3,  5,  7,  4,  2,  2,  6,  7,  4,  4,  3,  5, 10,  2,
#         5,  4,  6,  5,  8,  4,  4,  3,  8,  5,  6,  9,  8,  6,  3,  5,  5,
#         2,  4,  5,  5,  6,  5,  1,  5,  4,  5,  1, 10,  5,  6,  3,  5,  5,
# ...

# %%
stats.poisson.mean(mu=5)
# Out:
# 5.0

# %%
stats.poisson.var(mu=5)
# Out:
# 5.0

# %%
pmf = stats.poisson.pmf(k =arr , mu = 5)

# %%
cdf = stats.poisson.cdf(k=arr,mu=5)

# %% [markdown]
# # Q9. How mean and variance are related in Binomial distribution and Poisson distribution?

# %% [markdown]
# Solution :

# %% [markdown]
# Poisson Distribution:  mean = variance = lambda * time interval
#
# Binomial Distribution : mean = np , variance = npq

# %% [markdown]
# # Q10. In normal distribution with respect to mean position, where does the least frequent data appear

# %%
arr = np.random.normal(loc = 4 , scale = 2 , size = 1000)

# %%
stats.norm.ppf(q=0.68 , loc = 4 , scale = 2)
# Out:
# 4.935397598229017

# %%
z_score = ((-2)-4)/2

# %%
z_score
# Out:
# -3.0

# %% [markdown]
# In normal distribution, the least frequent data appears , 3 std away form the mean
